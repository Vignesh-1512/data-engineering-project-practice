# %%
# %pip uninstall -y de_project
# Out:
# Found existing installation: de-project 0.1.0
# Uninstalling de-project-0.1.0:
#   Successfully uninstalled de-project-0.1.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %pip install /Workspace/Shared/data/de_project-0.1.0-py3-none-any.whl
# Out:
# Processing /Workspace/Shared/data/de_project-0.1.0-py3-none-any.whl
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.12/site-packages (from de-project==0.1.0) (6.0.2)
# Installing collected packages: de-project
# Successfully installed de-project-0.1.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %restart_python

# %%
dbutils.library.restartPython()

# %%
from de_project.main import main
import inspect
print(inspect.signature(main))
# Out:
# (dataset=None, process_date=None, job=None)

# %%
from de_project.main import main
print(main)
# Out:
# <function main at 0xff337e18cb80>

# %%
dbutils.widgets.text("dataset", "events")
dbutils.widgets.text("process_date", "2026_01_05")

dataset = dbutils.widgets.get("dataset")
process_date = dbutils.widgets.get("process_date")

# %%
params = {
    "dataset": "events",
    "process_date": "2026_01_07",
    "job": "transform"
}

# %%
from de_project.main import main
main(**params)
# Out:
# Transforming data from temp view: events_2026_01_07
# Transformed TEMP VIEW created: events_transformed_2026_01_07
# +--------+-------+----------+------+-------------------+----------+---------------+
# |event_id|user_id|event_type|amount|event_time         |event_date|amount_category|
# +--------+-------+----------+------+-------------------+----------+---------------+
# |301     |U007   |LOGIN     |0     |2026-01-07 08:30:00|2026-01-07|LOW            |
# |302     |U008   |PURCHASE  |180   |2026-01-07 09:45:00|2026-01-07|LOW            |
# |303     |U007   |PURCHASE  |220   |2026-01-07 10:20:00|2026-01-07|LOW            |
# |304     |U009   |LOGIN     |0     |2026-01-07 11:00:00|2026-01-07|LOW            |
# |305     |U008   |LOGOUT    |0     |2026-01-07 13:15:00|2026-01-07|LOW            |
# |306     |U010   |PURCHASE  |400   |2026-01-07 16:40:00|2026-01-07|LOW            |
# +--------+-------+----------+------+-------------------+----------+---------------+

# %%
dbutils.fs.ls("/Volumes/de_catalog/raw/shared_data")
# Out:
# [FileInfo(path='dbfs:/Volumes/de_catalog/raw/shared_data/de_project-0.1.0-py3-none-any.whl', name='de_project-0.1.0-py3-none-any.whl', size=3288, modificationTime=1767623032000),
#  FileInfo(path='dbfs:/Volumes/de_catalog/raw/shared_data/events_2026_01_05.csv', name='events_2026_01_05.csv', size=285, modificationTime=1767694125000),
#  FileInfo(path='dbfs:/Volumes/de_catalog/raw/shared_data/events_2026_01_06.csv', name='events_2026_01_06.csv', size=284, modificationTime=1767694125000),
#  FileInfo(path='dbfs:/Volumes/de_catalog/raw/shared_data/events_2026_01_07.csv', name='events_2026_01_07.csv', size=284, modificationTime=1767699700000),
#  FileInfo(path='dbfs:/Volumes/de_catalog/raw/shared_data/events_2026_01_08.csv', name='events_2026_01_08.csv', size=280, modificationTime=1767699987000)]
